# %%
print("*************Welcome To Sahas Daily Needs**************")

#We made four different lists of menu,s_no,price,quantity of items
s_no=[1,2,3,4]
menu=["Ice_Creame","Biscuits","Milk","Wafers"]
price=[50,10,20,5]
quantity=[30,100,80,140]

#We created a function named shopping_cart to pass a group of statements to perform and call it out after all the program for final output
def shopping_cart():
    print("%0s %7s %15s %10s"%("s_no","menu","quantity","price"))
    print("%0d %14s %15s %10d"%(s_no[0],menu[0],quantity[0],price[0]))
    print("%0d %14s %15s %10d"%(s_no[1],menu[1],quantity[1],price[1]))
    print("%0d %14s %15s %10d"%(s_no[2],menu[2],quantity[2],price[2]))
    print("%0d %14s %15s %10d"%(s_no[3],menu[3],quantity[3],price[3]))

#We declare theevery value of menu list as a global variable to access it throughout the program and
#passing the if condition to take the quantity as per the limitation,if the user exceeded the quantity
#it will not pass rhe user to add that item to their cart
    global Ice_Creame
    Ice_Creame=int(input("Enter the no of Ice_Creame needed?"))
    if quantity[0]<Ice_Creame:
        print("Sorry!You have exceded the maximum quantity:= ",quantity[0])
        Ice_Creame=int(intput("Enter the no of Ice Creame needed:= "))
        
    global Biscuits
    Biscuits=int(input("Enter the no of packets of Biscuits needed?")) 
    if quantity[1]<Biscuits:
        print("Sorry!You have exceded the maximum quantity:= ",quantity[1])
        Biscuits=int(intput("Enter the no of packets of Biscuits needed:= "))
        
         
    global Milk
    Milk=int(input("Enter the no of packets of Milk needed?")) 
    if quantity[2]<Milk:
        print("Sorry!You have exceded the maximum quantity",quantity[2])
        Milk=int(intput("Enter the no of packets of Milk needed:= ")) 
        
    global Wafers
    Wafers=int(input("Enter the no of Wafers needed?")) 
    if quantity[3]<Wafers:
        print("Sorry!You have exceded the maximum quantity",quantity[3])
        Wafers=int(intput("Enter the no of Wafers needed:= "))
          
#To get the details of costumer we took these three as variables          
    Costumer_Name=input("Enter Name:= ")  
    Costumer_Address=input("Enter Address:= ")  
    Distance_For_Delievery=int(input("Enter distance in km:= "))    
 #Here it shows the indexing of quantity as per the menu item so that we can easily multiply the quantity ordered as per the unit price per quantity
    quantity[0]=quantity[0]-Ice_Creame
    quantity[1]=quantity[1]-Biscuits   
    quantity[2]=quantity[2]-Milk
    quantity[3]=quantity[3]-Wafers  
#We createwd a paymentbill function inside the shopping_cart function to amplify the bill details as per the cart function          
    def Paymentbill():
        print("Total Shopping Bill=")
        print("%0s %7s %15s %10s"%("s_no","menu","quantity","total_bill"))
        print("%0d %14s %15s %10d"%(s_no[0],menu[0],Ice_Creame,price[0]*Ice_Creame))
        print("%0d %14s %15s %10d"%(s_no[1],menu[1],Biscuits,price[1]*Biscuits))
        print("%0d %14s %15s %10d"%(s_no[2],menu[2],Milk,price[2]*Milk))
        print("%0d %14s %15s %10d"%(s_no[3],menu[3],Wafers,price[3]*Wafers))
#We took total bill and Delievery cahrges as two variables to print the whole total of order and charge the deliever fee as per distance        
        Total_Bill=(price[0]*Ice_Creame)+(price[1]*Biscuits)+(price[2]*Milk)+(price[3]*Wafers)
        Deleivery_Charges=(Distance_For_Delievery*3)
        print("Paymentbill")
        print("The total bill:=%3d"%Total_Bill)
        print("Total Paymentbill:=%3d"%(Total_Bill+Deleivery_Charges))
        print("Costumer_Name",Costumer_Name)
        print("Costumer_Address",Costumer_Address)
        a=input("Do you want to shopping continue? yes/no:= ")
        a=a.upper()
        if a=="yes":
            shopping_cart()
        else:
            print("Hope to see you again soon!")
            
        
    Paymentbill()              
shopping_cart()
# Out:
# *************Welcome To Sahas Daily Needs**************
# s_no    menu        quantity      price
# 1     Ice_Creame              30         50
# 2       Biscuits             100         10
# 3           Milk              80         20
# 4         Wafers             140          5
# Enter the no of Ice_Creame needed?5
# Enter the no of packets of Biscuits needed?10
# Enter the no of packets of Milk needed?12
# Enter the no of Wafers needed?25
# Enter Name:= Sahas Patharde
# Enter Address:= Chandrapur
# Enter distance in km:= 15
# Total Shopping Bill=
# s_no    menu        quantity total_bill
# 1     Ice_Creame               5        250
# 2       Biscuits              10        100
# 3           Milk              12        240
# 4         Wafers              25        125
# Paymentbill
# The total bill:=715
# Total Paymentbill:=760
# Costumer_Name Sahas Patharde
# Costumer_Address Chandrapur
# Do you want to shopping continue? yes/no:= yes
# Hope to see you again soon!
