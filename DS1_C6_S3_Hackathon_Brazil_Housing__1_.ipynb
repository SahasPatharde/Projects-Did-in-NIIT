# %%
import matplotlib.pyplot as plt             # to visualize
from tabulate import tabulate               # to print the table
import matplotlib as mat                    # to visualize 
import seaborn as sns                       # to visualize
import pandas as pd                         # for data reading
import numpy as np

# %%
df=pd.read_csv("/content/data (1) (1).csv")

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  int64
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum() #THERE ARE NO NULL VALUES
# Out:
# city                   0
# area                   0
# rooms                  0
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64

# %%
e_mean=df.groupby('city').mean()
i=pd.DataFrame(e_mean)
j=i.iloc[:,[7]]
j.plot.bar()

# %%
d1=df[(df.animal=='acept')&(df.furniture=='furnished')]
d1
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor animal  \
# 0           São Paulo    70      2         1               1      7  acept
# 8           São Paulo   152      2         2               1      3  acept
# 9      Rio de Janeiro    35      1         1               0      2  acept
# 10          São Paulo    26      1         1               0      2  acept
# 13          São Paulo    55      1         1               1      2  acept
# ...               ...   ...    ...       ...             ...    ...    ...
# 10659        Campinas   150      3         2               4      0  acept
# 10670       São Paulo   165      3         3               2      2  acept
# 10680       São Paulo   156      4         4               3      1  acept
# 10682    Porto Alegre   160      3         2               3      4  acept
# 10690  Rio de Janeiro   120      2         2               2      8  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
df.mean(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# area                    149.217920
# rooms                     2.506079
# bathroom                  2.236813
# parking spaces            1.609147
# floor                     5.067995
# hoa (R$)               1174.021698
# rent amount (R$)       3896.247194
# property tax (R$)       366.704358
# fire insurance (R$)      53.300879
# total (R$)             5490.487000
# dtype: float64

# %%
d2=df[(df.rooms==2)&(df.animal=='acept')&(df.furniture=='furnished')]
d2
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor animal  \
# 0           São Paulo    70      2         1               1      7  acept
# 8           São Paulo   152      2         2               1      3  acept
# 14          São Paulo   100      2         2               2     24  acept
# 83          São Paulo    64      2         2               2      4  acept
# 103    Rio de Janeiro    90      2         1               1      1  acept
# ...               ...   ...    ...       ...             ...    ...    ...
# 10596  Rio de Janeiro    60      2         1               0      2  acept
# 10628    Porto Alegre   140      2         3               2      7  acept
# 10629        Campinas    83      2         2               2      1  acept
# 10655  Rio de Janeiro   170      2         3               1      2  acept
# 10690  Rio de Janeiro   120      2         2               2      8  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
sns.displot(data=d2,y="city")

# %%
# IF THE CUSTOMER WANTS TO KEEP A PET AND NEEDS A HOUSE WHICH IS ALSO FULLY FURNISHED SAO PAULO AND RIO DE JANERIO IS THE BEST CITY WITH AVG OF 2 ROOMS PER HOUSE

# %%
d3=df[(df.rooms==2)&(df.bathroom==2)&(df.floor<=3)]
d3
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 8           São Paulo   152      2         2               1      3
# 16          São Paulo   110      2         2               1      1
# 89          São Paulo    85      2         2               2      3
# 130    Belo Horizonte    95      2         2               1      3
# 173         São Paulo    60      2         2               2      2
# ...               ...   ...    ...       ...             ...    ...
# 10463       São Paulo   150      2         2               2      0
# 10464  Rio de Janeiro    56      2         2               1      2
# 10555       São Paulo    90      2         2               1      3
# 10626       São Paulo   140      2         2               1      3
# 10629        Campinas    83      2         2               2      1
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 8          acept      furnished      1000             15000
# ...

# %%
sns.countplot(data=d3,y="city")

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of city")              
percentage = df["city"].value_counts()         
labels = list(df["city"].value_counts().index) 

sns.countplot(x = df["city"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  
plt.show()

# %%
d4=df[(df.rooms==2)&(df.animal=='acept')&(df.furniture=='not furnished')]
d4
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor animal  \
# 3        Porto Alegre    51      2         1               0      2  acept
# 6      Rio de Janeiro    72      2         1               0      7  acept
# 16          São Paulo   110      2         2               1      1  acept
# 18     Rio de Janeiro    56      2         1               0      8  acept
# 27     Belo Horizonte    64      2         2               1     11  acept
# ...               ...   ...    ...       ...             ...    ...    ...
# 10660       São Paulo    52      2         1               1      1  acept
# 10666  Rio de Janeiro    60      2         2               0     13  acept
# 10672       São Paulo   126      2         1               0     13  acept
# 10684  Rio de Janeiro    98      2         1               0      1  acept
# 10691       São Paulo    80      2         1               0      0  acept
#
# ...

# %%
sns.countplot(data=d4,y="city")

# %%
# for choosing a house in city which accepts pets but is not fully furnished , PORTO ALEGRE is the best choice.

# %%
d5=df[(df['hoa (R$)']<=1174)|(df['rent amount (R$)']<3896)|(df['total (R$)']<5490)|(df.rooms==2)]
d5
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 0           São Paulo    70      2         1               1      7
# 2        Porto Alegre    80      1         1               1      6
# 3        Porto Alegre    51      2         1               0      2
# 4           São Paulo    25      1         1               0      1
# 5           São Paulo   376      3         3               7      0
# ...               ...   ...    ...       ...             ...    ...
# 10686       São Paulo   150      3         3               2      8
# 10687    Porto Alegre    63      2         1               1      5
# 10689  Rio de Janeiro    70      3         3               0      8
# 10690  Rio de Janeiro   120      2         2               2      8
# 10691       São Paulo    80      2         1               0      0
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 0          acept      furnished      2065              3300
# ...

# %%
sns.displot(data=d5,y='city',kde='False')

# %%
#CONSIDERING THE BELOW AVERAGE HOA AS 1174 AND RENT AMOUNT AS 3896 WITH 2 ROOMS AND TOTAL OF 5490  PORTO ALEGRE IS THE BEST CITY.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 10692 non-null  object
#  1   area                 10692 non-null  int64
#  2   rooms                10692 non-null  int64
#  3   bathroom             10692 non-null  int64
#  4   parking spaces       10692 non-null  int64
#  5   floor                10692 non-null  int64
#  6   animal               10692 non-null  object
#  7   furniture            10692 non-null  object
#  8   hoa (R$)             10692 non-null  int64
#  9   rent amount (R$)     10692 non-null  int64
#  10  property tax (R$)    10692 non-null  int64
#  11  fire insurance (R$)  10692 non-null  int64
#  12  total (R$)           10692 non-null  int64
# dtypes: int64(10), object(3)
# memory usage: 1.1+ MB

# %%
d6=df[(df.floor==2)&(df.animal=='not acept')&(df.furniture=='not furnished')&(df['rent amount (R$)']<3896)&(df.city)]
d6
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 170      Porto Alegre    90      2         1               1      2
# 319    Belo Horizonte   135      4         3               2      2
# 345    Belo Horizonte   105      3         2               2      2
# 352    Rio de Janeiro   130      3         4               1      2
# 362         São Paulo   178      3         2               1      2
# ...               ...   ...    ...       ...             ...    ...
# 10334       São Paulo   180      2         2               0      2
# 10335  Belo Horizonte    65      2         1               1      2
# 10459       São Paulo    78      3         2               1      2
# 10492       São Paulo    30      1         1               0      2
# 10513       São Paulo   230      4         3               1      2
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 170    not acept  not furnished       550              1700
# ...

# %%
sns.displot(data=d6,x="city",hue="furniture",aspect=6)

# %%
#CONDIDERING THAT ANIMALS ARE NOT ALLOWED AND HOUSE IS NOT FURNISHED WITH ONLY 2 FLOORS AND RENT TO BE LESS THEN THE AVERAGE RENT(3896)
#SAO PAULO AND AND BELO HORIZONTE ARE THE BEST CITIES .

# %%
d7=df[(df.city=="Porto Alegre")&(df.floor==1)&(df.furniture=='furnished')]
d7
# Out:
#                city  area  rooms  bathroom  parking spaces  floor     animal  \
# 76     Porto Alegre    47      1         1               1      1  not acept
# 244    Porto Alegre    47      1         1               1      1  not acept
# 620    Porto Alegre    42      1         1               0      1      acept
# 1270   Porto Alegre    70      2         1               0      1      acept
# 1387   Porto Alegre    47      1         1               1      1  not acept
# 1644   Porto Alegre    35      2         1               0      1  not acept
# 2008   Porto Alegre    28      1         1               0      1      acept
# 2025   Porto Alegre    47      1         1               1      1  not acept
# 2114   Porto Alegre    47      1         1               1      1  not acept
# 2433   Porto Alegre    60      2         1               1      1      acept
# 2988   Porto Alegre    39      1         1               1      1  not acept
# ...

# %%
sns.countplot(data=d7,x="city",hue="animal")

# %%
#PORTE ALEGRE CITY IS THE BEST CITY IF THE CUSTOMER WANTS FURNISHED HOUSES AND DONT HAVE ANY KIND OF PETS WITH  A SINGLE FLOOR.

# %%
d7=df[(df.city=="Campinas")&(df.floor==1)&(df.furniture=='furnished')]
d7
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 162    Campinas    24      1         1               0      1  not acept
# 1068   Campinas    47      1         1               0      1      acept
# 1541   Campinas    76      1         1               1      1  not acept
# 2294   Campinas    60      2         1               1      1  not acept
# 2756   Campinas    72      3         1               1      1      acept
# 2985   Campinas    60      1         1               1      1      acept
# 3105   Campinas    58      2         1               1      1      acept
# 3787   Campinas    80      2         2               1      1      acept
# 5154   Campinas    57      2         1               1      1      acept
# 5824   Campinas    88      3         2               2      1      acept
# 5962   Campinas    40      1         1               1      1  not acept
# 6175   Campinas    92      3         2               3      1      acept
# ...

# %%
sns.countplot(data=d7,x="city",hue="animal")

# %%
# CAMPINAS CITY IS THE BEST CITY IF THE CUSTOMER WANTS FURNISHED HOUSES AND HAVE ANY KIND OF PETS WITH A SINGLE FLOOR.

# %%
d8=df[(df.area<149)&(df.bathroom<=2)&(df.rooms<=3)&(df.animal=="not acept")]
d8
# Out:
#                  city  area  rooms  bathroom  parking spaces  floor  \
# 4           São Paulo    25      1         1               0      1
# 21     Belo Horizonte    42      1         1               1     17
# 26          São Paulo    41      1         1               1      5
# 35       Porto Alegre    38      1         1               2     11
# 38          São Paulo    70      2         1               0      0
# ...               ...   ...    ...       ...             ...    ...
# 10665  Belo Horizonte    55      2         1               1      2
# 10667  Belo Horizonte    75      2         1               1      3
# 10671       São Paulo    84      2         2               1     16
# 10677       São Paulo    38      1         1               0     19
# 10687    Porto Alegre    63      2         1               1      5
#
#           animal      furniture  hoa (R$)  rent amount (R$)  \
# 4      not acept  not furnished         0               800
# ...

# %%
sns.displot(data=d8,x="city",hue="furniture",aspect=4)

# %%
# IF THE CUSTOMER WANTS A HOUSE WITH 2 BATHROOMS AND 3 ROOMS AND AREA TO BE LESS THAN AVG AREA OF (149),WHERE ANIMALS ARE NOT ALLOWED SAO PAULO IS THE BEST CITY AS IT PROVIDES WIDE 
#VARITY OF OPTIONS WITH  BOTH FURNISHED AND NON FURNISHED HOUSES.

# %%
df.head()
# Out:
#            city  area  rooms  bathroom  parking spaces  floor     animal  \
# 0     São Paulo    70      2         1               1      7      acept
# 1     São Paulo   320      4         4               0     20      acept
# 2  Porto Alegre    80      1         1               1      6      acept
# 3  Porto Alegre    51      2         1               0      2      acept
# 4     São Paulo    25      1         1               0      1  not acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
# 4  not furnished         0               800                 25
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# ...

# %%
df.mean(axis=0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# area                    149.217920
# rooms                     2.506079
# bathroom                  2.236813
# parking spaces            1.609147
# floor                     5.067995
# hoa (R$)               1174.021698
# rent amount (R$)       3896.247194
# property tax (R$)       366.704358
# fire insurance (R$)      53.300879
# total (R$)             5490.487000
# dtype: float64

# %%
#HEADING
#COMPARING RENT AMOUNT WITH FURNITURE

# %%
sns.lineplot(data=df,y='rent amount (R$)',x='furniture')

# %%
#INTERPREATATION : RENT AMOUNT DECREASES IF THE PROPERTY IS NOT FURNISHED

# %%
#HEADING
#COMPARING RENT AMOUNT WITH ANIMALS

# %%
sns.lineplot(data=df,x="animal",y="rent amount (R$)")

# %%
#INTERPREATATION IT IS CLEAR THAT IS ANIMAL IS NOT PRESENT THEN RENT AMOUNT DECREASES.

# %%
#HEADING
#COMPARING RENT AMOUNT WITH city 
# ie which city has most rent

# %%
sns.lineplot(data=df,x="city",y="rent amount (R$)")

# %%
#INTERPREATATION : IT IS CLEAR THAT SAO PAULO HAS THE HIGHEST RENT FOLLOWED BY RIO DE JANARIO AND BELO HORIZONTE

# %%
#HEADING
#COMPARING RENT AMOUNT WITH PARKING SPACE

# %%
sns.lineplot(data=df,x="parking spaces",y="rent amount (R$)")

# %%
#INTERPREATATION: IT IS CLEAR FROM THE DIAGRAM THAT IF NO IF PARKING SPACES INCREASES RENT AMOUNT ALSO INCREASES.

# %%
#HEADING
#COMPARING RENT AMOUNT WITH fire insurance (R$)

# %%
sns.lineplot(data=df,x="fire insurance (R$)",y="rent amount (R$)")

# %%
#INTERPREATATION : FIRE INSURANCE AMOUNT ALSO INCREASES AS RENT AMOUNT INCREASES.

# %%
d10=df[(df.city=="Belo Horizonte")&(df.floor==1)&(df.furniture=='furnished')]
d10
# Out:
#                 city  area  rooms  bathroom  parking spaces  floor     animal  \
# 1220  Belo Horizonte    30      1         1               1      1      acept
# 1254  Belo Horizonte   184      3         1               2      1      acept
# 2098  Belo Horizonte    80      3         2               2      1      acept
# 2306  Belo Horizonte   150      4         2               3      1      acept
# 2498  Belo Horizonte    22      1         1               1      1  not acept
# 3521  Belo Horizonte   181      4         2               2      1      acept
# 4055  Belo Horizonte    60      2         1               1      1      acept
# 4539  Belo Horizonte   224      4         4               4      1      acept
# 5524  Belo Horizonte    68      3         2               1      1      acept
# 5588  Belo Horizonte    22      1         1               1      1  not acept
# 6057  Belo Horizonte    27      1         1               0      1  not acept
# ...

# %%
sns.lineplot(data=d10,x="rent amount (R$)",y="area")

# %%
#INTERPREATATION: ACCORDING TO THE GRAPH AS AREA INCREASES RENT AMOUNT ALSO INCREASES.

# %%
d11=df[(df.city=="Porto Alegre")&(df.floor==3)&(df.furniture=='furnished')&(df.animal=="not acept")]
d11
# Out:
#                city  area  rooms  bathroom  parking spaces  floor     animal  \
# 1486   Porto Alegre    75      3         2               1      3  not acept
# 2671   Porto Alegre    65      2         1               1      3  not acept
# 2887   Porto Alegre   110      3         2               0      3  not acept
# 3114   Porto Alegre    70      2         1               0      3  not acept
# 3154   Porto Alegre    40      1         1               0      3  not acept
# 4070   Porto Alegre   110      3         2               1      3  not acept
# 6440   Porto Alegre    70      2         2               0      3  not acept
# 8270   Porto Alegre   222      3         2               2      3  not acept
# 8647   Porto Alegre    47      1         1               1      3  not acept
# 9326   Porto Alegre    40      1         1               0      3  not acept
# 10632  Porto Alegre    18      1         1               0      3  not acept
#
# ...

# %%
sns.lineplot(data=d11,y="rent amount (R$)",x="bathroom")

# %%
#INTERPREATATION: AS NO OF BATHROOMS INCREASES RENT ALSO INCREASES IF ANIMALS ARE NOT ALLOWED AND FLOOR ARE MORE THAN 3 WITH FULLY FURNISHED HOUSES.

# %%
#CONCLUSION:
# 1) BASED ON DIFFRENT CASE ABOVE Porto Alegre AND Belo Horizonte ARE THE BEST CITIES IF THE CUSTOMERS WANTS A HOUSE WITH LESS THAN AVG RENT AND WITH DIFFRENT FLOOR AND AREAS.
# 2) Porto Alegre AND Belo Horizonte AND Campinas ARE BEST CITIES WITH BOTH FURNISHED AND NON FURNISHED APPARTMENT .
# 3) Campinas	IS THE BEST CITY IF YOU HAVE A PET AND WANT A HOUSE WITH BELOW AVG RENT IF YOU WANT A POCKET FRIENDLY HOUSE .
# 4) IF THE PARKING SPACE AND FURNITURE IS ALLOWED WITH MORE NUMBER OF ROOMS ,FLOORS AND BATHROOM AND FIRE INSURANCE IS ALSO HIGH IF RENT IS HIGH.
